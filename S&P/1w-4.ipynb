# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r'C:\Users\siwoo\OneDrive\바탕 화면\데이터관련자료\통확실습코드\Stereo.xlsx')

df.tail()
# Out:
#    Week  No. of Commercials  Sales Volume
# 5     6                   1            38
# 6     7                   5            63
# 7     8                   3            48
# 8     9                   4            59
# 9    10                   2            46

# %%
#인덱스 지정 후 변경

df = pd.read_excel(r'C:\Users\siwoo\OneDrive\바탕 화면\데이터관련자료\통확실습코드\Stereo.xlsx', index_col='Week')

df.tail()
# Out:
#       No. of Commercials  Sales Volume
# Week
# 6                      1            38
# 7                      5            63
# 8                      3            48
# 9                      4            59
# 10                     2            46

# %%
#산점도
sns.scatterplot(x='No. of Commercials', y='Sales Volume', data=df)
# Out:
# <Axes: xlabel='No. of Commercials', ylabel='Sales Volume'>

# %%
#추세선 추가 -> seaborn에는 없음 -> 회귀선으로

sns.regplot(x='No. of Commercials', y='Sales Volume', data=df)
# Out:
# <Axes: xlabel='No. of Commercials', ylabel='Sales Volume'>

# %%
#confidence interval(신뢰구간) 제외

sns.regplot(x='No. of Commercials', y='Sales Volume', data=df, ci=None)
# Out:
# <Axes: xlabel='No. of Commercials', ylabel='Sales Volume'>
